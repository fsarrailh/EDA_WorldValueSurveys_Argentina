# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("WVS_TimeSeries_4_0.csv")

# %%
data.head(5)
# Out:
#   version                    doi  S002VS  S003 COUNTRY_ALPHA  COW_NUM  \
# 0   4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# 1   4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# 2   4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# 3   4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# 4   4-0-0  doi:10.14281/18241.22       4     8           ALB      339
#
#   COW_ALPHA  S004  S006      S007  ...     Y023A  Y023B     Y023C  Y024A  \
# 0       ALB    -4     1  80420001  ...       NaN    NaN  0.000000    NaN
# 1       ALB    -4     2  80420002  ...  0.000000    0.0  0.000000    NaN
# 2       ALB    -4     3  80420003  ...       NaN    0.0  0.000000    NaN
# 3       ALB    -4     4  80420004  ...  0.333333    1.0  0.555556    NaN
# 4       ALB    -4     5  80420005  ...  0.000000    0.0  0.222222    NaN
#
#    Y024B  Y024C  survself  tradrat5  TradAgg  SurvSAgg
# ...

# %%
data[data['COUNTRY_ALPHA']=='ARG'].head(50)
# Out:
#      version                    doi  S002VS  S003 COUNTRY_ALPHA  COW_NUM  \
# 9492   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9493   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9494   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9495   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9496   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9497   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9498   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9499   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9500   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9501   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9502   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# 9503   4-0-0  doi:10.14281/18241.22       5    32           ARG      160
# ...

# %%
data2=data[data['COUNTRY_ALPHA']=='ARG']

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7401 entries, 9492 to 16892
# Columns: 1045 entries, version to SurvSAgg
# dtypes: float64(53), int64(988), object(4)
# memory usage: 59.1+ MB

# %%
#grabo el dataframe a un nuevo csv solo de ARG
data2.to_csv('WVS_TimeSeries_ARGENTINA.csv')

# %% [markdown]
# ## RENAMING

# %%
data.rename(columns={'sexo': 'sex', 'grupo_etario': 'age_group', 'jurisdiccion_residencia': 'residence_jurisdiction', 'jurisdiccion_residencia_id': 'residence_jurisdiction_id', 'depto_residencia': 'residence_dept', 'depto_residencia_id': 'residence_dept_id', 'jurisdiccion_aplicacion': 'aplication_jurisdiction', 'jurisdiccion_aplicacion_id': 'aplication_jurisdiction_id', 'depto_aplicacion': 'aplication_dept', 'depto_aplicacion_id': 'aplication_dept_id', 'fecha_aplicacion': 'aplication_date', 'vacuna': 'vaccine', 'condicion_aplicacion': 'aplication_condition', 'orden_dosis': 'dose_order', 'lote_vacuna': 'vaccine_lot'}, inplace=True)

# %%
data.head(5)
# Out:
#    Unnamed: 0 sex age_group residence_jurisdiction  residence_jurisdiction_id  \
# 0          29   M     50-59           Buenos Aires                          6
# 1          72   F     40-49           Buenos Aires                          6
# 2         222   F     50-59           Buenos Aires                          6
# 3         225   F     60-69           Buenos Aires                          6
# 4         260   F     40-49           Buenos Aires                          6
#
#     residence_dept  residence_dept_id aplication_jurisdiction  \
# 0  Lomas de Zamora                490            Buenos Aires
# 1       San Isidro                756            Buenos Aires
# 2  Lomas de Zamora                490            Buenos Aires
# 3       Avellaneda                 35            Buenos Aires
# 4    Vicente López                861            Buenos Aires
#
#    aplication_jurisdiction_id  aplication_dept  aplication_dept_id  \
# ...

# %%
data2 = data.replace(to_replace=['Vicente López','General San Martín', 'Lanús', 'Morón'], value=['Vicente Lopez', 'General San Martin', 'Lanus', 'Moron'], regex=True)

# %%
data3 = data2.replace(to_replace=['Estratégico','18 a 59 años CON Factores de Riesgo', 'Salud', '60 o más años', '18 a 39 años SIN Factores de Riesgo', '40 a 49 años SIN Factores de Riesgo', '50 a 59 años SIN Factores de Riesgo', 'Otros'], value=['Strategic', '18 to 59 yo W/ Risk Factors', 'Health', '+60 yo', '18 to 39 yo WITHOUT Risk Factors', '40 to 49 yo WITHOUT Risk Factors', '50 to 59 yo WITHOUT Risk Factors', 'Ohters'], regex=True)

# %%
data3.head(30)
# Out:
#     Unnamed: 0 sex age_group residence_jurisdiction  \
# 0           29   M     50-59           Buenos Aires
# 1           72   F     40-49           Buenos Aires
# 2          222   F     50-59           Buenos Aires
# 3          225   F     60-69           Buenos Aires
# 4          260   F     40-49           Buenos Aires
# 5          264   M     40-49           Buenos Aires
# 6          303   F     18-29           Buenos Aires
# 7          728   M     40-49           Buenos Aires
# 8          875   F     80-89           Buenos Aires
# 9          924   M     40-49           Buenos Aires
# 10        1040   F     30-39           Buenos Aires
# 11        1177   F     50-59           Buenos Aires
# 12        1178   M     40-49           Buenos Aires
# 13        1179   F     40-49           Buenos Aires
# 14        1310   M     50-59           Buenos Aires
# 15        1509   M     30-39           Buenos Aires
# 16        1570   F     40-49           Buenos Aires
# ...

# %%
data3.to_csv('data_eng_trim_bsas_week1may21_comunas2.csv')

# %%
data.memory_usage(deep=True)
# Out:
# Index                                132
# sexo                          1157306750
# grupo_etario                  1236997032
# jurisdiccion_residencia       1404932575
# jurisdiccion_residencia_id     159612640
# depto_residencia              1443911260
# depto_residencia_id            159612640
# jurisdiccion_aplicacion       1405031322
# jurisdiccion_aplicacion_id     159612640
# depto_aplicacion              1441053668
# depto_aplicacion_id            159612640
# fecha_aplicacion              1336754168
# vacuna                        1312378957
# condicion_aplicacion          1884554066
# orden_dosis                    159612640
# lote_vacuna                   1296333667
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19951580 entries, 0 to 19951579
# Data columns (total 15 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   sexo                        object
#  1   grupo_etario                object
#  2   jurisdiccion_residencia     object
#  3   jurisdiccion_residencia_id  int64
#  4   depto_residencia            object
#  5   depto_residencia_id         int64
#  6   jurisdiccion_aplicacion     object
#  7   jurisdiccion_aplicacion_id  int64
#  8   depto_aplicacion            object
#  9   depto_aplicacion_id         int64
#  10  fecha_aplicacion            object
#  11  vacuna                      object
#  12  condicion_aplicacion        object
#  13  orden_dosis                 int64
#  14  lote_vacuna                 object
# dtypes: int64(5), object(10)
# memory usage: 2.2+ GB

# %%
#conversion a variables categoricas

# %%
data["sexo"] = data["sexo"].astype("category")

# %%
data.memory_usage(deep=True)
# Out:
# Index                                132
# sexo                            19951865
# grupo_etario                  1236997032
# jurisdiccion_residencia       1404932575
# jurisdiccion_residencia_id     159612640
# depto_residencia              1443911260
# depto_residencia_id            159612640
# jurisdiccion_aplicacion       1405031322
# jurisdiccion_aplicacion_id     159612640
# depto_aplicacion              1441053668
# depto_aplicacion_id            159612640
# fecha_aplicacion              1336754168
# vacuna                        1312378957
# condicion_aplicacion          1884554066
# orden_dosis                    159612640
# lote_vacuna                   1296333667
# dtype: int64

# %% [markdown]
# FILTERED

# %%
timeframe = (data['fecha_aplicacion'] >= "2021-05-31") & (data['fecha_aplicacion'] <= "2021-06-06")

# %%
data[timeframe].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2133780 entries, 20 to 19951578
# Data columns (total 15 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   sexo                        object
#  1   grupo_etario                object
#  2   jurisdiccion_residencia     object
#  3   jurisdiccion_residencia_id  int64
#  4   depto_residencia            object
#  5   depto_residencia_id         int64
#  6   jurisdiccion_aplicacion     object
#  7   jurisdiccion_aplicacion_id  int64
#  8   depto_aplicacion            object
#  9   depto_aplicacion_id         int64
#  10  fecha_aplicacion            object
#  11  vacuna                      object
#  12  condicion_aplicacion        object
#  13  orden_dosis                 int64
#  14  lote_vacuna                 object
# dtypes: int64(5), object(10)
# memory usage: 260.5+ MB

# %%
data_f = data[timeframe]

# %%
data_f.to_csv('data_trim_week1may21.csv')

# %% [markdown]
# Limito a provincia de BS AS

# %%
data_bsas = data_f.loc[data['jurisdiccion_residencia'] == "Buenos Aires"]

# %%
data_bsas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 689743 entries, 29 to 19951514
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   sexo                        689743 non-null  object
#  1   grupo_etario                689743 non-null  object
#  2   jurisdiccion_residencia     689743 non-null  object
#  3   jurisdiccion_residencia_id  689743 non-null  int64
#  4   depto_residencia            689743 non-null  object
#  5   depto_residencia_id         689743 non-null  int64
#  6   jurisdiccion_aplicacion     689743 non-null  object
#  7   jurisdiccion_aplicacion_id  689743 non-null  int64
#  8   depto_aplicacion            689743 non-null  object
#  9   depto_aplicacion_id         689743 non-null  int64
#  10  fecha_aplicacion            689743 non-null  object
#  11  vacuna                      689743 non-null  object
#  12  condicion_aplicacion        689743 non-null  object
# ...

# %%
#grabo el dataframe a un csv
data_bsas.to_csv('data_trim_bsas_week1may21.csv')

# %%
comunas = ['CABA', 'La Matanza', 'Tres de Febrero', 'Lomas de Zamora', 'General San Martín', 'Berazategui', 'Quilmes', 'Almirante Brown', 'Merlo', 'Lanús', 'Avellaneda', 'Moreno', 'Ezeiza', 'José C. Paz',
'Vicente López', 'San Isidro', 'San Fernando', 'Tigre', 'Malvinas Argentinas', 'San Miguel', 'Hurlingham', 'Morón', 'Ituzaingó', 'Esteban Echeverría']

# %%
comunas2 = ['CABA', 'La Matanza', 'Tres de Febrero', 'Lomas de Zamora', 'General San Martín', 'Quilmes', 'Lanús', 'Avellaneda',
'Vicente López', 'San Isidro', 'Morón']

# %%
data_bsas_comunas = data_bsas[(data_bsas['depto_residencia'].isin(comunas2))]

# %%
data_bsas_comunas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 202795 entries, 29 to 19951514
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   sexo                        202795 non-null  object
#  1   grupo_etario                202795 non-null  object
#  2   jurisdiccion_residencia     202795 non-null  object
#  3   jurisdiccion_residencia_id  202795 non-null  int64
#  4   depto_residencia            202795 non-null  object
#  5   depto_residencia_id         202795 non-null  int64
#  6   jurisdiccion_aplicacion     202795 non-null  object
#  7   jurisdiccion_aplicacion_id  202795 non-null  int64
#  8   depto_aplicacion            202795 non-null  object
#  9   depto_aplicacion_id         202795 non-null  int64
#  10  fecha_aplicacion            202795 non-null  object
#  11  vacuna                      202795 non-null  object
#  12  condicion_aplicacion        202795 non-null  object
# ...

# %%
data_bsas_comunas.head(50)
# Out:
#      sexo grupo_etario jurisdiccion_residencia  jurisdiccion_residencia_id  \
# 29      M        50-59            Buenos Aires                           6
# 72      F        40-49            Buenos Aires                           6
# 222     F        50-59            Buenos Aires                           6
# 225     F        60-69            Buenos Aires                           6
# 260     F        40-49            Buenos Aires                           6
# 264     M        40-49            Buenos Aires                           6
# 303     F        18-29            Buenos Aires                           6
# 728     M        40-49            Buenos Aires                           6
# 875     F        80-89            Buenos Aires                           6
# 924     M        40-49            Buenos Aires                           6
# 1040    F        30-39            Buenos Aires                           6
# ...

# %%
#grabo el dataframe a un csv
data_bsas_comunas.to_csv('data_trim_bsas_week1may21_comunas2.csv')

# %%
data[data['depto_aplicacion']=='Presidente Roque Sáenz Peña'].head(50)

# %%
#me daría la cantidad de vacunados con cada tipo de vacuna
data[data['jurisdiccion_aplicacion']=='Córdoba'].groupby(by=['vacuna']).sum()
#df.groupby(by=["b"]).sum()

# %%
data[data['jurisdiccion_aplicacion']=='Córdoba'].groupby(by=['lote_vacuna']).sum()

# %%
#me daría la cantidad de vacunas aplicadas
data[data['jurisdiccion_aplicacion']=='Córdoba'].groupby(by=['vacuna']).count()

# %%
data[data['sexo']=='F'].count()
